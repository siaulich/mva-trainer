# %%
import sys
sys.path.insert(0, '..')
from core.RootPreprocessor import RootPreprocessor, PreprocessorConfig, preprocess_root_file, preprocess_root_directory, DataSampleConfig
import numpy as np

# %%
threshold_config = DataSampleConfig(
    output_dir="../../DATA/",
    name="threshold_sample",
    input_dir="../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
        data_cuts={
            "truth_ttbar_mass": (None, 450000)
        }
    ), 
)

preprocess_root_directory(
    threshold_config,
)
# Out:
# Found 20 files in ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/.
# Starting processing...
#
#
# Processing file 1 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000010.output.root
# Total events in file: 2361172
# Events passing pre-selection: 1369920
# Events with invalid data (NaN/Inf): 3
# Processed 548444 events from user.kbehr.45417421._000010.output.root. Total events so far: 548444
#
#
# Processing file 2 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000019.output.root
# Total events in file: 130928
# Events passing pre-selection: 75851
# Events with invalid data (NaN/Inf): 0
# Processed 30404 events from user.kbehr.45417421._000019.output.root. Total events so far: 578848
#
#
# Processing file 3 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000005.output.root
# Total events in file: 1342224
# Events passing pre-selection: 778255
# Events with invalid data (NaN/Inf): 0
# Processed 312044 events from user.kbehr.45417421._000005.output.root. Total events so far: 890892
#
#
# Processing file 4 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000015.output.root
# Total events in file: 178666
# Events passing pre-selection: 103663
# Events with invalid data (NaN/Inf): 0
# Processed 41652 events from user.kbehr.45417421._000015.output.root. Total events so far: 932544
#
#
# Processing file 5 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000009.output.root
# Total events in file: 2365799
# Events passing pre-selection: 1371702
# Events with invalid data (NaN/Inf): 7
# Processed 548662 events from user.kbehr.45417421._000009.output.root. Total events so far: 1481206
#
#
# Processing file 6 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000016.output.root
# Total events in file: 393364
# Events passing pre-selection: 228137
# Events with invalid data (NaN/Inf): 0
# Processed 91580 events from user.kbehr.45417421._000016.output.root. Total events so far: 1572786
#
#
# Processing file 7 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000003.output.root
# Total events in file: 2078357
# Events passing pre-selection: 1205448
# Events with invalid data (NaN/Inf): 0
# Processed 481504 events from user.kbehr.45417421._000003.output.root. Total events so far: 2054290
#
#
# Processing file 8 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000006.output.root
# Total events in file: 2368158
# Events passing pre-selection: 1373669
# Events with invalid data (NaN/Inf): 2
# Processed 550549 events from user.kbehr.45417421._000006.output.root. Total events so far: 2604839
#
#
# Processing file 9 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000013.output.root
# Total events in file: 1379600
# Events passing pre-selection: 800688
# Events with invalid data (NaN/Inf): 1
# Processed 320187 events from user.kbehr.45417421._000013.output.root. Total events so far: 2925026
#
#
# Processing file 10 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000008.output.root
# Total events in file: 2130362
# Events passing pre-selection: 1235724
# Events with invalid data (NaN/Inf): 1
# Processed 493869 events from user.kbehr.45417421._000008.output.root. Total events so far: 3418895
#
#
# Processing file 11 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000014.output.root
# Total events in file: 178303
# Events passing pre-selection: 103574
# Events with invalid data (NaN/Inf): 0
# Processed 41464 events from user.kbehr.45417421._000014.output.root. Total events so far: 3460359
#
#
# Processing file 12 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000001.output.root
# Total events in file: 2465526
# Events passing pre-selection: 1431988
# Events with invalid data (NaN/Inf): 1
# Processed 574112 events from user.kbehr.45417421._000001.output.root. Total events so far: 4034471
#
#
# Processing file 13 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000004.output.root
# Total events in file: 1864129
# Events passing pre-selection: 1081950
# Events with invalid data (NaN/Inf): 2
# Processed 432780 events from user.kbehr.45417421._000004.output.root. Total events so far: 4467251
#
#
# Processing file 14 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000018.output.root
# Total events in file: 172201
# Events passing pre-selection: 99834
# Events with invalid data (NaN/Inf): 0
# Processed 40045 events from user.kbehr.45417421._000018.output.root. Total events so far: 4507296
#
#
# Processing file 15 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000011.output.root
# Total events in file: 2326502
# Events passing pre-selection: 1351018
# Events with invalid data (NaN/Inf): 2
# Processed 540464 events from user.kbehr.45417421._000011.output.root. Total events so far: 5047760
#
#
# Processing file 16 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000012.output.root
# Total events in file: 2372025
# Events passing pre-selection: 1376426
# Events with invalid data (NaN/Inf): 0
# Processed 551504 events from user.kbehr.45417421._000012.output.root. Total events so far: 5599264
#
#
# Processing file 17 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000020.output.root
# Total events in file: 379768
# Events passing pre-selection: 220260
# Events with invalid data (NaN/Inf): 0
# Processed 88015 events from user.kbehr.45417421._000020.output.root. Total events so far: 5687279
#
#
# Processing file 18 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000007.output.root
# Total events in file: 1485175
# Events passing pre-selection: 862848
# Events with invalid data (NaN/Inf): 4
# Processed 345174 events from user.kbehr.45417421._000007.output.root. Total events so far: 6032453
#
#
# Processing file 19 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000002.output.root
# Total events in file: 799109
# Events passing pre-selection: 463512
# Events with invalid data (NaN/Inf): 1
# Processed 185375 events from user.kbehr.45417421._000002.output.root. Total events so far: 6217828
#
#
# Processing file 20 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000017.output.root
# Total events in file: 449670
# Events passing pre-selection: 260634
# Events with invalid data (NaN/Inf): 0
# Processed 104483 events from user.kbehr.45417421._000017.output.root. Total events so far: 6322311
#
#
# Finished processing files. Total events processed: 6322311
#
# Merging data from all files...
# Merging key: lep_pt (1/74)
# Merging key: lep_eta (2/74)
# Merging key: lep_phi (3/74)
# Merging key: lep_e (4/74)
# Merging key: lep_charge (5/74)
# Merging key: lep_pid (6/74)
# Merging key: event_lepton_truth_idx (7/74)
# Merging key: jet_pt (8/74)
# Merging key: jet_eta (9/74)
# Merging key: jet_phi (10/74)
# Merging key: jet_e (11/74)
# Merging key: jet_b_tag (12/74)
# Merging key: event_jet_truth_idx (13/74)
# Merging key: N_jets (14/74)
# Merging key: N_bjets (15/74)
# Merging key: met_met (16/74)
# Merging key: met_phi (17/74)
# Merging key: m_l1j (18/74)
# Merging key: m_l2j (19/74)
# Merging key: dR_l1j (20/74)
# Merging key: dR_l2j (21/74)
# Merging key: dR_l1l2 (22/74)
# Merging key: weight_mc (23/74)
# Merging key: reco_mllbb (24/74)
# Merging key: truth_ttbar_mass (25/74)
# Merging key: truth_ttbar_pt (26/74)
# Merging key: truth_tt_boost_parameter (27/74)
# Merging key: truth_ttbar_px (28/74)
# Merging key: truth_ttbar_py (29/74)
# Merging key: truth_ttbar_pz (30/74)
# Merging key: truth_ttbar_e (31/74)
# Merging key: truth_ttbar_p (32/74)
# Merging key: truth_top_mass (33/74)
# Merging key: truth_top_pt (34/74)
# Merging key: truth_top_eta (35/74)
# Merging key: truth_top_phi (36/74)
# Merging key: truth_top_e (37/74)
# Merging key: truth_tbar_mass (38/74)
# Merging key: truth_tbar_pt (39/74)
# Merging key: truth_tbar_eta (40/74)
# Merging key: truth_tbar_phi (41/74)
# Merging key: truth_tbar_e (42/74)
# Merging key: truth_top_neutino_mass (43/74)
# Merging key: truth_top_neutino_pt (44/74)
# Merging key: truth_top_neutino_eta (45/74)
# Merging key: truth_top_neutino_phi (46/74)
# Merging key: truth_top_neutino_e (47/74)
# Merging key: truth_top_neutrino_px (48/74)
# Merging key: truth_top_neutrino_py (49/74)
# Merging key: truth_top_neutrino_pz (50/74)
# Merging key: truth_tbar_neutino_mass (51/74)
# Merging key: truth_tbar_neutino_pt (52/74)
# Merging key: truth_tbar_neutino_eta (53/74)
# Merging key: truth_tbar_neutino_phi (54/74)
# Merging key: truth_tbar_neutino_e (55/74)
# Merging key: truth_tbar_neutrino_px (56/74)
# Merging key: truth_tbar_neutrino_py (57/74)
# Merging key: truth_tbar_neutrino_pz (58/74)
# Merging key: truth_top_lepton_e (59/74)
# Merging key: truth_tbar_lepton_e (60/74)
# Merging key: truth_top_lepton_px (61/74)
# Merging key: truth_top_lepton_py (62/74)
# Merging key: truth_top_lepton_pz (63/74)
# Merging key: truth_tbar_lepton_px (64/74)
# Merging key: truth_tbar_lepton_py (65/74)
# Merging key: truth_tbar_lepton_pz (66/74)
# Merging key: nu_flows_neutrino_px (67/74)
# Merging key: nu_flows_neutrino_py (68/74)
# Merging key: nu_flows_neutrino_pz (69/74)
# Merging key: nu_flows_antineutrino_px (70/74)
# Merging key: nu_flows_antineutrino_py (71/74)
# Merging key: nu_flows_antineutrino_pz (72/74)
# Merging key: truth_initial_parton_num_gluons (73/74)
# Merging key: mc_event_number (74/74)
# Saving merged data to npz file...
# Merged data saved to ../../DATA/threshold_sample.npz

# %%
boosted_config = DataSampleConfig(
    output_dir="../../DATA/",
    name="boosted_sample",
    input_dir="../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
        data_cuts={
            "truth_ttbar_mass": (450000, None)
        }
    ), 
)

preprocess_root_directory(
    boosted_config,
)
# Out:
# Found 20 files in ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/.
# Starting processing...
#
#
# Processing file 1 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000010.output.root
# Total events in file: 2361172
# Events passing pre-selection: 1369920
# Events with invalid data (NaN/Inf): 3
# Processed 821473 events from user.kbehr.45417421._000010.output.root. Total events so far: 821473
#
#
# Processing file 2 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000019.output.root
# Total events in file: 130928
# Events passing pre-selection: 75851
# Events with invalid data (NaN/Inf): 0
# Processed 45447 events from user.kbehr.45417421._000019.output.root. Total events so far: 866920
#
#
# Processing file 3 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000005.output.root
# Total events in file: 1342224
# Events passing pre-selection: 778255
# Events with invalid data (NaN/Inf): 0
# Processed 466211 events from user.kbehr.45417421._000005.output.root. Total events so far: 1333131
#
#
# Processing file 4 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000015.output.root
# Total events in file: 178666
# Events passing pre-selection: 103663
# Events with invalid data (NaN/Inf): 0
# Processed 62011 events from user.kbehr.45417421._000015.output.root. Total events so far: 1395142
#
#
# Processing file 5 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000009.output.root
# Total events in file: 2365799
# Events passing pre-selection: 1371702
# Events with invalid data (NaN/Inf): 7
# Processed 823033 events from user.kbehr.45417421._000009.output.root. Total events so far: 2218175
#
#
# Processing file 6 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000016.output.root
# Total events in file: 393364
# Events passing pre-selection: 228137
# Events with invalid data (NaN/Inf): 0
# Processed 136557 events from user.kbehr.45417421._000016.output.root. Total events so far: 2354732
#
#
# Processing file 7 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000003.output.root
# Total events in file: 2078357
# Events passing pre-selection: 1205448
# Events with invalid data (NaN/Inf): 0
# Processed 723944 events from user.kbehr.45417421._000003.output.root. Total events so far: 3078676
#
#
# Processing file 8 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000006.output.root
# Total events in file: 2368158
# Events passing pre-selection: 1373669
# Events with invalid data (NaN/Inf): 2
# Processed 823118 events from user.kbehr.45417421._000006.output.root. Total events so far: 3901794
#
#
# Processing file 9 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000013.output.root
# Total events in file: 1379600
# Events passing pre-selection: 800688
# Events with invalid data (NaN/Inf): 1
# Processed 480500 events from user.kbehr.45417421._000013.output.root. Total events so far: 4382294
#
#
# Processing file 10 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000008.output.root
# Total events in file: 2130362
# Events passing pre-selection: 1235724
# Events with invalid data (NaN/Inf): 1
# Processed 741854 events from user.kbehr.45417421._000008.output.root. Total events so far: 5124148
#
#
# Processing file 11 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000014.output.root
# Total events in file: 178303
# Events passing pre-selection: 103574
# Events with invalid data (NaN/Inf): 0
# Processed 62110 events from user.kbehr.45417421._000014.output.root. Total events so far: 5186258
#
#
# Processing file 12 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000001.output.root
# Total events in file: 2465526
# Events passing pre-selection: 1431988
# Events with invalid data (NaN/Inf): 1
# Processed 857875 events from user.kbehr.45417421._000001.output.root. Total events so far: 6044133
#
#
# Processing file 13 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000004.output.root
# Total events in file: 1864129
# Events passing pre-selection: 1081950
# Events with invalid data (NaN/Inf): 2
# Processed 649168 events from user.kbehr.45417421._000004.output.root. Total events so far: 6693301
#
#
# Processing file 14 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000018.output.root
# Total events in file: 172201
# Events passing pre-selection: 99834
# Events with invalid data (NaN/Inf): 0
# Processed 59789 events from user.kbehr.45417421._000018.output.root. Total events so far: 6753090
#
#
# Processing file 15 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000011.output.root
# Total events in file: 2326502
# Events passing pre-selection: 1351018
# Events with invalid data (NaN/Inf): 2
# Processed 810552 events from user.kbehr.45417421._000011.output.root. Total events so far: 7563642
#
#
# Processing file 16 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000012.output.root
# Total events in file: 2372025
# Events passing pre-selection: 1376426
# Events with invalid data (NaN/Inf): 0
# Processed 824922 events from user.kbehr.45417421._000012.output.root. Total events so far: 8388564
#
#
# Processing file 17 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000020.output.root
# Total events in file: 379768
# Events passing pre-selection: 220260
# Events with invalid data (NaN/Inf): 0
# Processed 132245 events from user.kbehr.45417421._000020.output.root. Total events so far: 8520809
#
#
# Processing file 18 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000007.output.root
# Total events in file: 1485175
# Events passing pre-selection: 862848
# Events with invalid data (NaN/Inf): 4
# Processed 517670 events from user.kbehr.45417421._000007.output.root. Total events so far: 9038479
#
#
# Processing file 19 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000002.output.root
# Total events in file: 799109
# Events passing pre-selection: 463512
# Events with invalid data (NaN/Inf): 1
# Processed 278136 events from user.kbehr.45417421._000002.output.root. Total events so far: 9316615
#
#
# Processing file 20 of 20...
#
# Processing ROOT file: ../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/user.kbehr.45417421._000017.output.root
# Total events in file: 449670
# Events passing pre-selection: 260634
# Events with invalid data (NaN/Inf): 0
# Processed 156151 events from user.kbehr.45417421._000017.output.root. Total events so far: 9472766
#
#
# Finished processing files. Total events processed: 9472766
#
# Merging data from all files...
# Merging key: lep_pt (1/74)
# Merging key: lep_eta (2/74)
# Merging key: lep_phi (3/74)
# Merging key: lep_e (4/74)
# Merging key: lep_charge (5/74)
# Merging key: lep_pid (6/74)
# Merging key: event_lepton_truth_idx (7/74)
# Merging key: jet_pt (8/74)
# Merging key: jet_eta (9/74)
# Merging key: jet_phi (10/74)
# Merging key: jet_e (11/74)
# Merging key: jet_b_tag (12/74)
# Merging key: event_jet_truth_idx (13/74)
# Merging key: N_jets (14/74)
# Merging key: N_bjets (15/74)
# Merging key: met_met (16/74)
# Merging key: met_phi (17/74)
# Merging key: m_l1j (18/74)
# Merging key: m_l2j (19/74)
# Merging key: dR_l1j (20/74)
# Merging key: dR_l2j (21/74)
# Merging key: dR_l1l2 (22/74)
# Merging key: weight_mc (23/74)
# Merging key: reco_mllbb (24/74)
# Merging key: truth_ttbar_mass (25/74)
# Merging key: truth_ttbar_pt (26/74)
# Merging key: truth_tt_boost_parameter (27/74)
# Merging key: truth_ttbar_px (28/74)
# Merging key: truth_ttbar_py (29/74)
# Merging key: truth_ttbar_pz (30/74)
# Merging key: truth_ttbar_e (31/74)
# Merging key: truth_ttbar_p (32/74)
# Merging key: truth_top_mass (33/74)
# Merging key: truth_top_pt (34/74)
# Merging key: truth_top_eta (35/74)
# Merging key: truth_top_phi (36/74)
# Merging key: truth_top_e (37/74)
# Merging key: truth_tbar_mass (38/74)
# Merging key: truth_tbar_pt (39/74)
# Merging key: truth_tbar_eta (40/74)
# Merging key: truth_tbar_phi (41/74)
# Merging key: truth_tbar_e (42/74)
# Merging key: truth_top_neutino_mass (43/74)
# Merging key: truth_top_neutino_pt (44/74)
# Merging key: truth_top_neutino_eta (45/74)
# Merging key: truth_top_neutino_phi (46/74)
# Merging key: truth_top_neutino_e (47/74)
# Merging key: truth_top_neutrino_px (48/74)
# Merging key: truth_top_neutrino_py (49/74)
# Merging key: truth_top_neutrino_pz (50/74)
# Merging key: truth_tbar_neutino_mass (51/74)
# Merging key: truth_tbar_neutino_pt (52/74)
# Merging key: truth_tbar_neutino_eta (53/74)
# Merging key: truth_tbar_neutino_phi (54/74)
# Merging key: truth_tbar_neutino_e (55/74)
# Merging key: truth_tbar_neutrino_px (56/74)
# Merging key: truth_tbar_neutrino_py (57/74)
# Merging key: truth_tbar_neutrino_pz (58/74)
# Merging key: truth_top_lepton_e (59/74)
# Merging key: truth_tbar_lepton_e (60/74)
# Merging key: truth_top_lepton_px (61/74)
# Merging key: truth_top_lepton_py (62/74)
# Merging key: truth_top_lepton_pz (63/74)
# Merging key: truth_tbar_lepton_px (64/74)
# Merging key: truth_tbar_lepton_py (65/74)
# Merging key: truth_tbar_lepton_pz (66/74)
# Merging key: nu_flows_neutrino_px (67/74)
# Merging key: nu_flows_neutrino_py (68/74)
# Merging key: nu_flows_neutrino_pz (69/74)
# Merging key: nu_flows_antineutrino_px (70/74)
# Merging key: nu_flows_antineutrino_py (71/74)
# Merging key: nu_flows_antineutrino_pz (72/74)
# Merging key: truth_initial_parton_num_gluons (73/74)
# Merging key: mc_event_number (74/74)
# Saving merged data to npz file...
# Merged data saved to ../../DATA/boosted_sample.npz

# %%
threshold_config = DataSampleConfig(
    output_dir="../../DATA/",
    name="threshold_sample",
    input_dir="../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
        data_cuts={
            "truth_ttbar_mass": (None, 450000)
        }
    ), 
)

preprocess_root_directory(
    threshold_config,
)

# %%
toponium_config = DataSampleConfig(
    output_dir="../../DATA/",
    name="toponium",
    input_dir="../../root_data/user.kbehr.802380.Py8EG_Toponium_2L.DAOD_PHYS.e8562_s4231_r13145_r13146_p6697.250918-v1_output",
    preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
    ), 
)

preprocess_root_directory(
    toponium_config,
)

# %%
# Example: Preprocess to NPZ format
toponium_config = DataSampleConfig(
    output_dir="../../DATA/",
    name="nominal",
    input_dir="../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
        preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        lepton_parton_match_format="old",
    ), 
)

preprocess_root_directory(
    toponium_config,
)

# %%
# Example: Preprocess to NPZ format
toponium_config = DataSampleConfig(
    output_dir="../../DATA/",
    name="test_sample",
    input_dir="../../root_data/mc202507/user.kbehr.410472.PhPy8EG.DAOD_PHYS.e6348_s3681_r13145_r13146_p6697.250627-v1_output/",
        preprocessor_config=PreprocessorConfig(
        tree_name="reco",
        save_initial_parton_info=True,
        save_nu_flows=True,
        lepton_parton_match_format="old",
    ), 
    max_events=1_000_000,
)

preprocess_root_directory(
    toponium_config,
)
